# %%
import numpy as np
from dataset import SymbolicDataset

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
import pytorch_lightning as pl
from transformers import BertConfig, BertModel

# %env CUDA_VISIBLE_DEVICES=3
# Out:
# env: CUDA_VISIBLE_DEVICES=3

# %%
dataset = SymbolicDataset('/zfsauton/datasets/ArgoRL/brianyan/carla_data/')
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)
# Out:
# 100%|██████████| 458/458 [00:02<00:00, 184.26it/s]
# Number of samples: 743036

# %%
sample = next(iter(dataloader))
obs, action, reward, done, next_obs = sample
ego_features = obs['ego_features']
bounding_box = ego_features['bounding_box']

other_features = obs['vehicle_features']
other_idx = list(other_features.keys())[0]
other_bounding_box = other_features[other_idx]['bounding_box']

# %%
x = torch.tensor(bounding_box)[::2]
y = torch.tensor(other_bounding_box)[::2]

def positional_encoding(p, L=10):
    return torch.stack([torch.sin(2**i * np.pi * p) for i in range(L)] + [torch.cos(2**i * np.pi * p) for i in range(L)], dim=-1)

# %%
class TransformerAgent(pl.LightningModule):
    def __init__(self, embedding_size=128):
        super().__init__()

        self.embedding_size = embedding_size

        config = BertConfig(
            vocab_size=1, # we do our own embeddings
            num_attention_heads=8,
            hidden_size=self.embedding_size,
            intermediate_size=512,
        )
        self.model = BertModel(config)

        self.action_predictor = nn.Sequential(
            nn.Linear(embedding_size, 128),
            nn.ReLU(),
            nn.Linear(128, 2),
            nn.Tanh()
        )

        self.segment_embedding = nn.Embedding(3, 128)

        self.vehicle_encoder = nn.Sequential(
            nn.Linear(2, 128),
            nn.ReLU(),
            nn.Linear(128, self.embedding_size)
        )

        self.ego_encoder = nn.Sequential(
            nn.Linear(3, 128),
            nn.ReLU(),
            nn.Linear(128, self.embedding_size)
        )

        self.waypoint_encoder = nn.Linear(1, 128)

    def make_ego_token(self, obs_dict):
        ego_features = obs_dict['ego_features']
        ego_vehicle_token = self.make_vehicle_token(ego_features)
        ego_encodings = self.ego_encoder(
            torch.FloatTensor([obs_dict['light'], obs_dict['next_orientation'], obs_dict['dist_to_trajectory']]).cuda()
        )
        ego_token = ego_vehicle_token + ego_encodings
        return ego_token

    def make_vehicle_token(self, actor_features, is_ego=False):
        positions = torch.tensor(actor_features['bounding_box'])[::2]
        positional_encodings = positional_encoding(positions, L=32).cuda().reshape(-1,128)

        feature_encodings = self.vehicle_encoder(
            torch.FloatTensor([actor_features['theta'], actor_features['speed']]).cuda()
        )

        token = feature_encodings + positional_encodings
        return token

    def make_waypoint_tokens(self, waypoints):
        waypoints = torch.tensor(waypoints)[:,:2]
        positional_encodings = positional_encoding(waypoints, L=32).cuda().reshape(-1,128)

        feature_encodings = self.waypoint_encoder(
            torch.FloatTensor([i for i in range(len(waypoints))]).reshape(-1,1).cuda()
        )
        token = feature_encodings + positional_encodings
        return token

    def forward(self, obs):
        ego_token = self.make_ego_token(obs)
        if obs['vehicle_features']:
            vehicle_tokens = torch.stack([self.make_vehicle_token(obs['vehicle_features'][idx]) for idx in obs['vehicle_features']]).reshape(-1,128)
        else:
            vehicle_tokens = torch.zeros((0,128)).cuda()
        waypoint_tokens = self.make_waypoint_tokens(obs['next_waypoints'])
        tokens = torch.cat([ego_token, vehicle_tokens, waypoint_tokens], dim=0)

        output = self.model(
            inputs_embeds=tokens[None].float()
        )
        pooler_output = output[1]
        pred_action = agent.action_predictor(pooler_output)

        return pred_action

    def training_step(self, batch, batch_idx, optimizer_idx):
        obs, action, reward, done, next_obs = batch
        pred_action = self.forward(obs)
        loss = F.mse_loss(pred_action, action)
        self.log('train/bc_loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        obs, action, reward, done, next_obs = batch
        pred_action = self.forward(obs)
        loss = F.mse_loss(pred_action, action)
        self.log('val/bc_loss', loss)
        return loss

    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=1e-4)

# %%
agent = TransformerAgent().cuda()

# %%
for obs, action, reward, done, next_obs in dataloader:
    pred_action = agent.forward(obs)
    print(pred_action)
# Out:
# tensor([[ 0.0860, -0.0394]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0212, 0.0019]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0380, 0.0086]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1101, -0.0357]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0474, 0.0219]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1028, -0.0358]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0414, -0.0039]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1183, -0.0194]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1230, -0.0267]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0211, 0.0021]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0009, 0.0131]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0052, -0.0036]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1067, -0.0504]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1199, -0.0358]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0968, -0.0547]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0993, -0.0377]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0934, -0.0448]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0096, 0.0065]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0464, -0.0101]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0792, -0.0450]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0207, 0.0201]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0136,  0.0018]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0954, -0.0467]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1061, -0.0363]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0247, -0.0275]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0179, 0.0314]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0998, -0.0553]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1040, -0.0325]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0348, -0.0424]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0078, 0.0175]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1066, -0.0086]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0458, -0.0440]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1116, -0.0222]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0118, -0.0098]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0329, 0.0197]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0893, -0.0253]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0342, -0.0378]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0226, -0.0782]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0653, 0.0009]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0870, -0.0318]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1018, -0.0497]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0749, -0.0481]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0291, 0.0048]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0200,  0.0202]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0116, -0.0578]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0356, -0.0798]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1056, -0.0396]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1162, -0.0094]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0083,  0.0315]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0270, 0.0204]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0367, -0.0136]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0249, 0.0095]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0161, 0.0012]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0306, 0.0216]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1072, -0.0449]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1065, -0.0381]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0148, -0.0003]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0107, -0.0034]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0728, -0.0150]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0991, -0.0385]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0541, -0.0476]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0065, 0.0215]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0979, -0.0434]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0194, -0.0026]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0077, -0.0310]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0392, -0.0326]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0070, -0.0695]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0035, -0.0038]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0999, -0.0349]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0180, 0.0210]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0840, -0.0548]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0024, -0.0203]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1083, -0.0291]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0515, 0.0088]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0846, -0.0545]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0312, 0.0228]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1162, -0.0477]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0168,  0.0194]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0083, -0.0148]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0168, 0.0109]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0999, -0.0305]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0717, -0.0287]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0304, -0.0115]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0940, -0.0305]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1015, -0.0266]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1076, -0.0410]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0372, 0.0170]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0282, 0.0155]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0851, -0.0373]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1084, -0.0575]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1028, -0.0372]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[-0.0135,  0.0187]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1029, -0.0358]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1052, -0.0503]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1023, -0.0252]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.
], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0311, 0.0433]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0995, -0.0439]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0877, -0.0102]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0022, 0.0212]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0981, -0.0450]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0104, 0.0219]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0002, 0.0119]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0329, -0.0403]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0051, -0.0488]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1067, -0.0534]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0965, -0.0509]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0929, -0.0283]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0027, 0.0714]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0444, -0.0062]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0071, 0.0005]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1187, -0.0340]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0875, -0.0679]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0316, -0.0038]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0342, 0.0252]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0353, -0.0594]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.1094, -0.0446]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0044, 0.0566]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0853, -0.0400]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[0.0185, 0.0034]], device='cuda:0', grad_fn=<TanhBackward>)
# tensor([[ 0.0977, -0.0363]], device='cuda:0', grad_fn=<TanhBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-dce9d9797ff2> in <module>
#       1 for obs, action, reward, done, next_obs in dataloader:
# ----> 2     pred_action = agent.forward(obs)
#       3     print(pred_action)
#
# <ipython-input-78-81f94c3619ed> in forward(self, obs)
#      79
#      80         output = self.model(
# ---> 81             inputs_embeds=tokens[None].float()
#      82         )
#      83         pooler_output = output[1]
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     979             output_attentions=output_attentions,
#     980             output_hidden_states=output_hidden_states,
# --> 981             return_dict=return_dict,
#     982         )
#     983         sequence_output = encoder_outputs[0]
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     573                     encoder_attention_mask,
#     574                     past_key_value,
# --> 575                     output_attentions,
#     576                 )
#     577
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     459             head_mask,
#     460             output_attentions=output_attentions,
# --> 461             past_key_value=self_attn_past_key_value,
#     462         )
#     463         attention_output = self_attention_outputs[0]
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     392             encoder_attention_mask,
#     393             past_key_value,
# --> 394             output_attentions,
#     395         )
#     396         attention_output = self.output(self_outputs[0], hidden_states)
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/transformers/models/bert/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     274         else:
#     275             key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 276             value_layer = self.transpose_for_scores(self.value(hidden_states))
#     277
#     278         query_layer = self.transpose_for_scores(mixed_query_layer)
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/carla/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# KeyboardInterrupt:
